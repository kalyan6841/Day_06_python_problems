# %%
#ATM Machine simulation
balance = 10000
choice = input("enter B to check balance or W to with draw: ")
if choice == "B":
    print("your balance is :",balance)
elif choice == "W":
     amount = float(input("Enter amount to withdraw: "))
if amount<=balance:
    balance = balance - amount
    print("withdrawal succesful")
    print("remaining balance:", balance)
else:
    print("insufficient balance")
    print("invalid option")
# Out:
# enter B to check balance or W to with draw:  W
# Enter amount to withdraw:  5000
# withdrawal succesful
# remaining balance: 5000.0

# %%
#GRETTING BASED ON TIME
hour = int(input("enter current hour (0-23): "))
if 5<=hour <=11:
    print("good morning")
elif 12<= hour<=16:
    print("good afternoon")
elif 17<= hour <=20:
    print("good evening")
elif 0 <= hour<=23:
    print("good evening")
else:
    print("invalid hour")
# Out:
# enter current hour (0-23):  10
# good morning

# %%
#copoun code discount
price = float(input("Enter price: "))
coupon = input("enter coupon code: ")
if coupon =="SAVE10":
    discount = price*0.10
    final_price = price - discount
    print("discount applied")
    print("final price:", final_price)
else:
    print("invalid coupon")
    print("final prive:", price)
# Out:
# Enter price:  5000
# enter coupon code:  SAVE10
# discount applied
# final price: 4500.0

# %%
#Grade calculator validation
marks = int(input("enter marks: "))
if marks < 0 or marks> 100:
    print("invlid marks")
elif marks>=90:
    print("grade A")
elif marks>= 75:
    print("grade B")
elif marks>= 50:
    print("grade C")
else:
    print("fail")
# Out:
# enter marks:  65
# grade C

# %%
#calculator with menu 
print("1. addition")
print("2. subtraaction")
print("3. multiplication")
print("4. division")
choice = int(input ("choose operation (1-4): "))
a = float(input("enter first number:"))
b = float(input("enter second number: "))
if choice == 1:
    print("result:", a+b)
elif choice == 2:
    print("result:", a-b)
elif choice == 3:
    print("result:", a*b)
elif choice == 4:
    print("result:", a/b)
else:
    print("invalid choice")
# Out:
# 1. addition
# 2. subtraaction
# 3. multiplication
# 4. division
# choose operation (1-4):  3
# enter first number: 20
# enter second number:  10
# result: 200.0
